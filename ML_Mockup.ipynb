# %%
# Import dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC
import pandas as pd
import tensorflow as tf

# %%
#  Import and read the data
cannabis_df = pd.read_csv("county_product_data.csv")
cannabis_df
# Out:
#             Date         Product Type      County Month Name Month Year  \
# 0      10/1/2016            Usable MJ       Baker    October  10/1/2016
# 1      10/1/2016            Usable MJ       Baker    October  10/1/2016
# 2      10/1/2016  Concentrate/Extract   Clackamas    October  10/1/2016
# 3      10/1/2016      Edible/Tincture   Clackamas    October  10/1/2016
# 4      10/1/2016                Other   Clackamas    October  10/1/2016
# ...          ...                  ...         ...        ...        ...
# 32416   4/1/2022            Usable MJ       Wasco      April   4/1/2022
# 32417   4/1/2022            Usable MJ  Washington      April   4/1/2022
# 32418   4/1/2022            Usable MJ  Washington      April   4/1/2022
# 32419   4/1/2022            Usable MJ     Yamhill      April   4/1/2022
# 32420   4/1/2022            Usable MJ     Yamhill      April   4/1/2022
#
#       Tooltip Date  Market Share County      Sales  Sales Detail
# 0           Oct-16               100.00   58637.51      58637.51
# 1           Oct-16               100.00     441.00        441.00
# 2           Oct-16                15.14     803.20        803.20
# 3           Oct-16                 9.31     359.68        359.68
# 4           Oct-16                 1.13      30.00         30.00
# ...            ...                  ...        ...           ...
# 32416       Apr-22                48.13    3980.86       3980.86
# 32417       Apr-22                47.34   27466.81      27466.81
# 32418       Apr-22                47.34  172242.21     172242.21
# 32419       Apr-22                45.68    5089.02       5089.02
# 32420       Apr-22                45.68   34264.89      34264.89
#
# [32421 rows x 9 columns]

# %%
# Determine the number of unique values in each column.
cannabis_df.nunique()
# Out:
# Date                      67
# Product Type               7
# County                    31
# Month Name                12
# Month Year                67
# Tooltip Date              67
# Market Share County     3783
# Sales                  29709
# Sales Detail           29709
# dtype: int64

# %%
# Look at Product Types for binning
can_counts = cannabis_df.groupby(["Product Type"]).count()["Sales"]
can_counts
# Out:
# Product Type
# Concentrate/Extract                              8420
# Edible/Tincture                                  5125
# Industrial Hemp                                   352
# Industrial Hemp Commodity/Product                3209
# Inhalable Product with Non-Cannabis Additives     945
# Other                                            6541
# Usable MJ                                        7829
# Name: Sales, dtype: int64

# %%
#This is just a mockup. Much of this will change when we populate with actual data
# Determine which values to replace if counts are less than ...?
replace_can = list(can_counts[can_counts < 900].index)

# Replace in dataframe
for app in replace_can:
    can_df.Product Type = cannabis_df.DATA_TYPE.replace(app,"Other")
    
# Check to make sure binning was successful
# I need to change "Product Type" to camel form so this can load. 
cannabis_df.Product Type.value_counts()

# %%
# Look at CLASSIFICATION value counts for binning
class_counts = cannabis_df.CLASSIFICATION.value_counts()

# %%
# Determine which values to replace if counts are less than ..?
replace_class = list(class_counts[class_counts < 900].index)

# Replace in dataframe
for cls in replace_class:
    cannabis_df.CLASSIFICATION = cannabis_df.CLASSIFICATION.replace(cls,"Other")
    
# Check to make sure binning was successful
application_df.CLASSIFICATION.value_counts()

# %%
# Generate our categorical variable lists
cannabis_cat = cannabis_df.dtypes[cannabis_df.dtypes == "object"].index.tolist()
# Check the number of unique values in each column
cannabis_df[cannabis_cat].nunique()

# %%
# Create a OneHotEncoder instance
enc = OneHotEncoder(sparse=False)

# Fit and transform the OneHotEncoder using the categorical variable list
encode_df = pd.DataFrame(enc.fit_transform(cannabis_df[cannabis_cat]))

# Add the encoded variable names to the dataframe
encode_df.columns = enc.get_feature_names(cannabis_cat)
encode_df.head()

# %%
# Split our preprocessed data into our features and target arrays
y = cannabis_df.IS_SUCCESSFUL.values #Once again, Mockup. This will change
X = cannabis_df.drop(columns=["IS_SUCCESSFUL"]).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=33, stratify=y)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the logistic regression model
log_classifier = LogisticRegression(solver="lbfgs",max_iter=200)

# Train the model
log_classifier.fit(X_train,y_train)

# Evaluate the model
y_pred = log_classifier.predict(X_test)
print(f" Logistic regression model accuracy: {accuracy_score(y_test,y_pred):.3f}")

# %%
# Create a random forest classifier.
rf_model = RandomForestClassifier(n_estimators=128, random_state=33)

# Fitting the model
rf_model = rf_model.fit(X_train_scaled, y_train)

# Evaluate the model
y_pred = rf_model.predict(X_test_scaled)
print(f" Random forest predictive accuracy: {accuracy_score(y_test,y_pred):.3f}")

# %%
# Define the model - deep neural net
number_input_features = len(X_train_scaled[0])
hidden_nodes_layer1 = 24
hidden_nodes_layer2 = 12

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))


# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customize metrics
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)

# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")

# %%
# Export our model to HDF5 file
nn.save("cannabis_data.h5")

# %%
# Export data to a file
txt_file.write(cannabis_data.csv)
